# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
# %matplotlib inline
dataset_path = "../dataset/lfw_funneled/"

# %% [markdown]
# #### Showing sample of images checking to see if there are unusual image

# %%
from easyimages import EasyImageList
easy_list = EasyImageList.from_multilevel_folder(dataset_path)
easy_list
# Out:
# <ImageList with 13233 EasyImages [filter OFF]>

# %%
easy_list.html(sample=300, size=100, by_class=False)
# Out:
# <div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=['Malik_Mahmud'] src='../dataset/lfw_funneled/Malik_Mahmud/Malik_Mahmud_0001.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=['Laura_Bush'] src='../dataset/lfw_funneled/Laura_Bush/Laura_Bush_0008.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=['Guillermo_Coria'] src='../dataset/lfw_funneled/Guillermo_Coria/Guillermo_Coria_0010.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=['Stefano_Accorsi'] src='../dataset/lfw_funneled/Stefano_Accorsi/Stefano_Accorsi_0002.jpg'/></div><div class="zoom"><img style='width: 100px; height: 100px; margin: 1px; float: left; border: 0px solid black;'title=['Kate_Starbird'] src='../dataset/lfw_funneled/Kat
# ...

# %%
people = []
features = []
images_aspect_ratios = []
for person in os.listdir(dataset_path):
    path = os.path.join(dataset_path,person)
    label = person
    imagesCount = os.listdir(path)
    if(len(imagesCount)>=20):
        for img in os.listdir(path):
    #         if the identity has over or 20 images
            try:
                imgPath = os.path.join(path, img)
                person_img = cv2.imread(imgPath)
                person_img = person_img[30:, 30:]
                # append image aspect_ratio for ploting
                images_aspect_ratios.append(person_img.shape[1] / person_img.shape[0])
#                 person_img = cv2.cvtColor(person_img, cv2.COLOR_RGB2GRAY)
                people.append(person)
                features.append(person_img)
            except:
                continue
        
features = np.asarray(features)
people = np.asarray(people)

# %%
import tensorflow as tf
from keras import layers
import keras

data_augmentation = keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.4),
])
# Out:
# 2023-11-16 07:52:08.139929: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-16 07:52:08.463130: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-16 07:52:08.466187: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-16 07:52:10.416385: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
plt.figure(figsize=(8, 7))
for i in range(6):
  augmented_image = data_augmentation(features[i])
  ax = plt.subplot(2, 3, i + 1)
  plt.imshow(augmented_image.numpy()/255)
  plt.axis("off")

# %%
print(features.shape)
# Out:
# (3023, 220, 220, 3)

# %% [markdown]
# ## Plotting images aspec ratios distribution

# %%
sns.histplot(data=images_aspect_ratios)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# <font color='red'> UNIFORM DISTRIBUTION - All of the images have the same aspect ratios </font>

# %%
# df['Target'].describe()

# target_counts = df['Target'].value_counts()
# valid_targets = target_counts[target_counts >= 20].index
# filtered_df = df[df['Target'].isin(valid_targets)]
# filtered_df.reset_index(inplace=True, drop=True)
# filtered_df.head()

# %%
# plt.figure(figsize=(16,9))
# sns.histplot(filtered_df['Target'])
# plt.xticks(rotation=90, fontsize=8)
# plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Cut frontal face and verify pixel histogram¶

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

img = features[0]
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

faces = face_classifier.detectMultiScale(
    img,     
    scaleFactor=1.2,
    minNeighbors=5,     
    minSize=(40, 40)
)

for x,y,w,h in faces:
    img = img[y:y+h,x:x+w]
    

plt.subplot(1, 2, 1)
plt.imshow(img, cmap = plt.cm.gray)

hist, bins = np.histogram(img.flatten(), 256, [0, 256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()

plt.subplot(1, 2, 2)
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(), 256, [0,256], color='r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ### Apply filter and normalize pixel¶

# %%
listFace = []
for index in np.arange(len(features)):
    img = features[index]
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    faces = face_classifier.detectMultiScale(
        img,     
        scaleFactor=1.2,
        minNeighbors=5,     
        minSize=(20, 20)
    )

    for x,y,w,h in faces:
        img = img[y:y+h,x:x+w]
        
    if img.shape[1] > 0 and img.shape[0] > 0:
        img = cv2.resize(img, (60,60), interpolation = cv2.INTER_AREA)

        hist, bins = np.histogram(img.flatten(), 256, [0, 256])

        cdf = hist.cumsum()
        cdf_normalized = cdf * hist.max() / cdf.max(),
        
        cdf_m = np.ma.masked_equal(cdf, 0)
        cdf_m = (cdf_m - cdf_m.min())*255 / (cdf_m.max()-cdf_m.min())
        cdf = np.ma.filled(cdf_m, 0).astype('uint8')

        img = cdf[img]
        #_, img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
        listFace.append(img.reshape(60*60))
    else:
        people[index] = float("NaN")

# %%
listFace = np.array(listFace)
listFace.shape
# Out:
# (3011, 3600)

# %%
listFace.shape
# Out:
# (3011, 3600)

# %%
print(len(listFace), len(people))
# Out:
# 3011 3023

# %%
img = listFace[0].reshape(60,60)
plt.subplot(1, 2, 1)
plt.imshow(img, cmap = plt.cm.gray)

hist, bins = np.histogram(img.flatten(), 256, [0, 256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()

plt.subplot(1, 2, 2)
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(), 256, [0,256], color='r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
people = pd.DataFrame(people)

# %%
people.replace('nan', np.nan, inplace=True)
people.rename(columns={0: 'Target'}, inplace=True)

# %%
people.dropna(inplace = True)
people.reset_index(inplace = True, drop=True)

# %%
people['Target'].unique()
# Out:
# array(['Jack_Straw', 'Gray_Davis', 'John_Negroponte', 'David_Beckham',
#        'Jennifer_Lopez', 'Gloria_Macapagal_Arroyo', 'Jacques_Chirac',
#        'Jiang_Zemin', 'Hans_Blix', 'Atal_Bihari_Vajpayee',
#        'George_Robertson', 'Michael_Bloomberg', 'Jennifer_Capriati',
#        'Kofi_Annan', 'Luiz_Inacio_Lula_da_Silva', 'George_W_Bush',
#        'Arnold_Schwarzenegger', 'Laura_Bush', 'Recep_Tayyip_Erdogan',
#        'Donald_Rumsfeld', 'Ariel_Sharon', 'Igor_Ivanov', 'Angelina_Jolie',
#        'Winona_Ryder', 'Carlos_Menem', 'Bill_Clinton', 'Hamid_Karzai',
#        'Tom_Daschle', 'Naomi_Watts', 'Jean_Chretien',
#        'Megawati_Sukarnoputri', 'John_Ashcroft', 'Serena_Williams',
#        'Paul_Bremer', 'Lleyton_Hewitt', 'Ricardo_Lagos',
#        'Jeremy_Greenstock', 'Guillermo_Coria', 'Nestor_Kirchner',
#        'Vladimir_Putin', 'Vicente_Fox', 'Tiger_Woods', 'Pete_Sampras',
#        'Lindsay_Davenport', 'Alvaro_Uribe', 'Saddam_Hussein',
# ...

# %%
people.shape
# Out:
# (3011, 1)

# %%
dic_class = {value: index for index, value in enumerate(people['Target'].unique())}

people['Target'] = people['Target'].apply(lambda value: dic_class[value])

# %%
print(len(listFace),len(people) )
# Out:
# 3011 3011

# %%
# x = pd.DataFrame(listFace)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(x.values, people.values, random_state=42, stratify=people.values, test_size=0.4)

# imageMean = np.array(list(map(lambda index: X_train[:, index].mean(), np.arange(X_train.shape[1]))))
imageMean = np.array(list(map(lambda index: listFace[:, index].mean(), np.arange(listFace.shape[1]))))
plt.imshow(imageMean.reshape(60,60), cmap = plt.cm.gray, interpolation='sinc')

# %%
dataMean = listFace - imageMean
dataMean.shape
# Out:
# (3011, 3600)

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95, copy=False)
pc_df = pca.fit_transform(dataMean)

# %%
sum(pca.explained_variance_ratio_) * 100
# Out:
# 95.01142272146109

# %%
plt.imshow(listFace[0].reshape(60,60),
              cmap = plt.cm.gray, interpolation='nearest',
              clim=(0, 255))
plt.xlabel(str(60*60) + ' components', fontsize = 14)
plt.title('Original Image', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.figure(figsize=(20,10))
length_pca = pca.n_components_

for index, value in enumerate(range(0, length_pca, 5)):
    data_original = np.dot(pc_df[:,:value], pca.components_[:value, :]) + imageMean
    plt.subplot(1, int((length_pca/5)+1), int((value/5)+1))
    plt.imshow(data_original[0].reshape(60, 60),
                  cmap = plt.cm.gray)
    plt.xlabel(str(value) + ' components', fontsize = 10)
    plt.title('{:.2f}%'.format(sum(pca.explained_variance_ratio_[:value]) * 100), fontsize = 9.5)

data_original = np.dot(pc_df[:,:40], pca.components_[:40, :]) + imageMean
plt.subplot(1, 9, 9)
plt.imshow(data_original[0].reshape(60, 60),
              cmap = plt.cm.gray)
plt.xlabel(str(40) + ' components', fontsize = 10)
plt.title('{:.2f}% Explained Variance'.format(sum(pca.explained_variance_ratio_[:40]) * 100), fontsize = 9.5)
# Out:
# Text(0.5, 1.0, '75.46% Explained Variance')

# %%
df = pd.DataFrame(pc_df, people['Target'])

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    Target            0            1            2            3           4  \
# 0       0 -1149.497161  2874.499320  -135.198464  -961.440106 -184.083607
# 1       0 -2300.551602  1118.051889  -871.702847   529.323876 -680.285668
# 2       0  -606.568585  -220.764254 -1839.552900   192.163050  -12.260933
# 3       0  -203.642682  1347.131530 -1438.300823 -1058.876146  361.859963
# 4       0 -2945.740327  1761.800426  -120.579147   955.286929 -684.373127
#
#              5            6            7           8  ...        285  \
# 0   319.157950   295.393036  -319.559815 -262.851854  ...  32.532653
# 1   -31.723994  1229.179412   207.312443  287.714662  ... -16.689412
# 2  1189.190856  1144.563943   237.363328 -479.590169  ...  91.392533
# 3  -394.338978   505.279312 -1096.601815 -283.675012  ...  54.616319
# 4  -745.115169  -562.725890    23.809285   28.781657  ... -23.728153
#
#          286        287         288        289         290        291  \
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
X = df.drop('Target', axis=1)
y = df['Target']
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, random_state=42, stratify=y, test_size=0.2)

# %%
X_train.shape
# Out:
# (2408, 295)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip(),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
from numpy import newaxis
X_train = X_train[:,:,newaxis]
print(X_train.shape, X_test.shape)
X_train_augmented = data_augmentation(X_train, training=True)
X_train_augmented_2d = np.squeeze(X_train_augmented, axis=-1)
# Out:
# (2408, 295, 1) (603, 295)

# %%
X_train_augmented = data_augmentation(X_train, training=True)

# %%
X_train_augmented_2d = np.squeeze(X_train_augmented, axis=-1)

# %%
print(X_train_augmented_2d.shape)
# Out:
# (2408, 295)

# %%
param_grid = {'C': [0.1, 1, 10, ],  
              'gamma': [1, 0.1, 0.01], 
              'gamma':['scale', 'auto'],
              'kernel': ['linear','poly', 'sigmoid', 'rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
svc = SVC(kernel='linear', class_weight='balanced', gamma='scale', C=0.1)
svc.fit(X_train_augmented_2d, y_train)
# Out:
# SVC(C=0.1, class_weight='balanced', kernel='linear')

# %%
from sklearn.metrics import accuracy_score

predictions = svc.predict(X_test)

accuracy_score(predictions, y_test)
# Out:
# 0.003316749585406302

# %%
from sklearn.metrics import accuracy_score

predictions = svc.predict(X_train)

accuracy_score(predictions, y_train)
# Out:
# 1.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
images_scaled = scaler.fit_transform(listFace)

# %%
sns.histplot(images_scaled[0], kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)
images_pca = pca.fit_transform(images_scaled)

# %%
print(images_pca.shape, people.shape)
# Out:
# (3010, 306) (3012, 1)

# %%
people
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 3013  61
# 3014  61
# 3015  61
# 3016  61
# 3017  61
#
# [3018 rows x 1 columns]

# %%
df = pd.DataFrame(images_pca, people['Target'])
df.reset_index(inplace=True)
df.head()
# Out:
#    Target          0          1          2          3          4          5  \
# 0       0  28.947989  39.930650  -8.734200 -10.678379  -3.823718  -4.745707
# 1       0  33.966559  12.459865 -14.722414  13.563202  -1.050655 -10.478357
# 2       0   5.271793   1.895912 -21.291563  10.867988  15.822116 -20.468539
# 3       0  10.166771  16.676261 -24.757231 -11.422685   5.834470   0.349506
# 4       0  42.295722  15.990198  -7.420428  18.085054 -12.935060  11.977512
#
#            6         7          8  ...       296       297       298  \
# 0  -7.067521 -1.952485  -5.528418  ...  0.330179 -0.757725  0.408194
# 1 -12.923967  4.046141  10.029686  ...  1.103261  0.782449  0.948247
# 2  -8.111508  6.069231  -2.563227  ... -0.688473 -0.155932  0.202040
# 3 -10.641412 -9.525214   1.418337  ...  1.123552  0.532106  1.317119
# 4   0.765874 -1.814065  -1.795989  ... -0.283820 -0.461802  0.360878
#
#         299       300       301       302       303       304       305
# ...

# %%
X = df.drop('Target', axis=1)
y = df['Target']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=0.4)
param_grid = {'C': [0.1, 1, 10, ],  
              'gamma': [1, 0.1, 0.01], 
              'gamma':['scale', 'auto'],
              'kernel': ['linear','poly', 'sigmoid', 'rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(X_train, y_train) 
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
from sklearn.metrics import classification_report, confusion_matrix 
grid_predictions = grid.predict(X_test) 
   
# print classification report 
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.45      0.53        11
#            1       0.33      0.30      0.32        10
#            2       0.47      0.58      0.52        12
#            3       0.30      0.25      0.27        12
#            4       0.83      0.62      0.71         8
#            5       0.89      0.89      0.89        18
#            6       0.36      0.48      0.41        21
#            7       0.50      0.50      0.50         8
#            8       0.44      0.44      0.44        16
#            9       0.62      0.50      0.56        10
#           10       0.80      0.44      0.57         9
#           11       0.33      0.14      0.20         7
#           12       0.67      0.35      0.46        17
#           13       0.83      0.42      0.56        12
#           14       0.52      0.68      0.59        19
#           15       0.71      0.88      0.78       211
# ...

# %%
svc = SVC(kernel='linear', class_weight='balanced', gamma='scale', C=0.1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=0.4)
svc.fit(X_train, y_train)
# Out:
# SVC(C=0.1, class_weight='balanced', kernel='linear')

# %%
from sklearn.metrics import accuracy_score

predictions = svc.predict(X_train)

accuracy_score(predictions, y_train)
# Out:
# 1.0
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.612 total time=   2.1s
# [CV 2/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.188 total time=   1.8s
# [CV 2/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.177 total time=   2.1s
# [CV 5/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.612 total time=   1.9s
# [CV 3/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.175 total time=   2.0s
# [CV 1/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.177 total time=   5.3s
# [CV 3/5] END .....C=1, gamma=scale, kernel=poly;, score=0.252 total time=   3.5s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.368 total time=   2.5s
# [CV 5/5] END ....C=1, gamma=auto, kernel=linear;, score=0.612 total time=   1.7s
# [CV 3/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.188 total time=   1.6s
# [CV 2/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.177 total time=   5.3s
# ...
